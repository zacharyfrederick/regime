# %% [markdown]
# # Regime analysis
#
# Regime characterization and backtesting. Load master_features.parquet; overlay regime labels on price/vol; optional walk-forward validation (e.g. vectorbt).

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import config
import pandas as pd

if config.MASTER_FEATURES_PATH.exists():
    df = pd.read_parquet(config.MASTER_FEATURES_PATH)
    print("Master shape:", df.shape)
    print(df["date"].min(), "to", df["date"].max())
else:
    print("Run pipeline first.")
