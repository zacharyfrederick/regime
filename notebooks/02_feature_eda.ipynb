# %% [markdown]
# # Feature EDA
#
# Distributions, correlations, and missingness for `master_features.parquet`. Data path from config.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import config
import pandas as pd

df = pd.read_parquet(config.MASTER_FEATURES_PATH) if config.MASTER_FEATURES_PATH.exists() else None
if df is not None:
    print(df.shape)
    print(df.isna().sum().sort_values(ascending=False).head(15))
